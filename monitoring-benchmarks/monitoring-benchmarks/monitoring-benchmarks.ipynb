# %% [markdown]
# # Assumptions
# TODO env vars and params and so: define first as variables in a Python cell, then read from JSON and launch in another script that will launch several clusters

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
import os
from IPython.display import display, HTML

# %%
df = pd.DataFrame(data={'col1': [1, 2], 'col2': [3, 4]})
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df.plot.line(y='col2')
# Out:
# <AxesSubplot: >
